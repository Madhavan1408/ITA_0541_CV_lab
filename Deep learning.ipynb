# %%
print("om gam ganadi pathaye namaha")
# Out:
# om gam ganadi pathaye namaha

# %%
# Importing libraries
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class LSTM(nn.Module):
    def __init__(self,input_size:int,hidden_size:int,num_layers:int=2,batch_first:bool=False,bidirectional:bool=False,dropout:float =0.0):
        super().__init__()
        self.hidden_size=hidden_size
        self.num_layers=num_layers
        self.bidirectional=bidirectional
        self.num_directional=2 if bidirectional else 1
        self.lstm=nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            dropout-droput if num_layers>1 else 0.0,
            batch_first=batfh_first,
            bidirectianal=bidirectional
        )
        self.layer_Norm=nn.LayerNorm(hidden_size * self.num_directional)
        self.dropout=nn.Dropout(dropout)
        self.fc=nn.Linear(hidden_state* self.num_directional,output_size)

# %%
def forward(self,x,h0=None,c0=None):
    batch_size=x.size(0)
    if h0 is None:
        h0=torch.zeros(
            self.numm_layers* self.num_directions,
            batch_size,
            self.hidden_size,
            device=x.device
        )
    if c0 is None:
        c0=torch.zero_like(h0)
    out,(hn,cn)=self.lstm(x,(h0,c0))
    out=self.layer_norm(out)
    last_out=self.dropout(out[:,-1,:])
    prediction=self.fc(last_out)
    all_out=self.dropout(out)
    all_predictions=self.fc(all_out)
    return predictions,all_predictions,(hn,cn)

# %%
# !git add .
# Out:
# ...
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> course-conflcter
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached course-conflcter
# hint:
# hint: See "git help submodule" for more information.
# hint: Disable this message with "git config set advice.addEmbeddedRepo false"
# ...
# ...
# ...
# error: 'git_demo/' does not have a commit checked out
# fatal: adding files failed

# %%
# !git add "Deep learning.ipynb"

# %%
# !git commit -m "First commit"
# Out:
# [main (root-commit) 8eb0c0e] First commit
#  2 files changed, 1318 insertions(+)
#  create mode 100644 Deep learning.ipynb
#  create mode 100644 kmeans_dataset.csv

# %%
# !git remote add origin https://github.com/Madhavan1408/deep_learning_implementation.git
# Out:
# error: remote origin already exists.

# %%
# !git push origin main
# Out:
# To https://github.com/Madhavan1408/deep_learning_implementation.git
#  * [new branch]      main -> main
